# %%
import pandas as pd

# %%
df = pd.read_csv('customer_shopping_behavior.csv')
df.head(5)
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %%
df.isnull().sum()
# Out:
# Customer ID                0
# Age                        0
# Gender                     0
# Item Purchased             0
# Category                   0
# Purchase Amount (USD)      0
# Location                   0
# Size                       0
# Color                      0
# Season                     0
# Review Rating             37
# Subscription Status        0
# Shipping Type              0
# Discount Applied           0
# Promo Code Used            0
# Previous Purchases         0
# Payment Method             0
# Frequency of Purchases     0
# dtype: int64

# %%
df[(df['Age'] > 67) & (df['Size'] == "L")]
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 40             41   69    Male        Handbag  Accessories
# 108           109   70    Male          Socks     Clothing
# 211           212   69    Male          Skirt     Clothing
# 311           312   69    Male          Jeans     Clothing
# 484           485   68    Male            Hat  Accessories
# ...           ...  ...     ...            ...          ...
# 3524         3525   69  Female          Pants     Clothing
# 3558         3559   68  Female       Backpack  Accessories
# 3626         3627   69  Female         Blouse     Clothing
# 3704         3705   68  Female     Sunglasses  Accessories
# 3841         3842   68  Female          Jeans     Clothing
#
#       Purchase Amount (USD)      Location Size     Color  Season  \
# 40                       76     Louisiana    L     Beige  Winter
# 108                      79       Montana    L    Purple  Spring
# ...

# %%
             
df.query("Age > 69 and Size == 'XL'")
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 685           686   70    Male         Blouse     Clothing
# 958           959   70    Male       Sneakers     Footwear
# 1723         1724   70    Male          Scarf  Accessories
# 2068         2069   70    Male        Jewelry  Accessories
# 3818         3819   70  Female       Sneakers     Footwear
# 3874         3875   70  Female        Sweater     Clothing
#
#       Purchase Amount (USD)       Location Size    Color  Season  \
# 685                      71  Massachusetts   XL  Magenta  Winter
# 958                      53     Washington   XL    Beige  Winter
# 1723                     20       New York   XL     Gold  Spring
# 2068                     81        Vermont   XL    Black  Summer
# 3818                     41         Oregon   XL   Indigo  Winter
# 3874                     54         Nevada   XL    Beige  Summer
#
#       Review Rating Subscription Status   Shipping Type Discount Applied  \
# ...

# %%
df.sort_values('Age').head(3)
# Out:
#       Customer ID  Age Gender Item Purchased     Category  \
# 2224         2225   18   Male         Gloves  Accessories
# 2241         2242   18   Male         Jacket    Outerwear
# 1612         1613   18   Male          Skirt     Clothing
#
#       Purchase Amount (USD)   Location Size     Color  Season  Review Rating  \
# 2224                     25   Nebraska    L  Charcoal  Winter            4.3
# 2241                     77   Maryland    M    Purple  Summer            3.5
# 1612                     68  Wisconsin    M    Indigo  Summer            4.4
#
#      Subscription Status  Shipping Type Discount Applied Promo Code Used  \
# 2224                  No       Standard               No              No
# 2241                  No  Free Shipping               No              No
# 1612                  No       Standard              Yes             Yes
#
#       Previous Purchases Payment Method Frequency of Purchases
# ...

# %%
df.sort_values(['Review Rating', 'Age'], ascending=[True, True]).head(5)
# Out:
#       Customer ID  Age Gender Item Purchased     Category  \
# 1449         1450   18   Male          Socks     Clothing
# 1219         1220   19   Male        Sweater     Clothing
# 1358         1359   19   Male          Scarf  Accessories
# 2522         2523   20   Male           Belt  Accessories
# 251           252   21   Male        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size     Color  Season  \
# 1449                     41       New York    L  Lavender  Winter
# 1219                     23        Vermont    M      Gold  Winter
# 1358                     22       Nebraska   XL      Pink  Spring
# 2522                     53  Massachusetts    S     Olive  Winter
# 251                      51        Wyoming   XL      Gold  Winter
#
#       Review Rating Subscription Status   Shipping Type Discount Applied  \
# 1449            2.5                  No    Store Pickup              Yes
# ...

# %%
df.groupby('Category')[['Review Rating']].mean()
# Out:
#              Review Rating
# Category
# Accessories       3.769976
# Clothing          3.721537
# Footwear          3.793771
# Outerwear         3.745652

# %%
df['Review Rating'] = df.groupby('Category')['Review Rating'].transform(lambda x: x.fillna(x.median()))

# %%
df.isnull().sum()
# Out:
# Customer ID               0
# Age                       0
# Gender                    0
# Item Purchased            0
# Category                  0
# Purchase Amount (USD)     0
# Location                  0
# Size                      0
# Color                     0
# Season                    0
# Review Rating             0
# Subscription Status       0
# Shipping Type             0
# Discount Applied          0
# Promo Code Used           0
# Previous Purchases        0
# Payment Method            0
# Frequency of Purchases    0
# dtype: int64

# %%
df.columns = df.columns.str.lower().str.replace(" ", "_")

# %%
df.head()
# Out:
#    customer_id  age gender item_purchased  category  purchase_amount_(usd)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         location size      color  season  review_rating subscription_status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %%
df = df.rename(columns={"purchase_amount_(usd)":"purchase_amount"})
df.head(5)
# Out:
#    customer_id  age gender item_purchased  category  purchase_amount  \
# 0            1   55   Male         Blouse  Clothing               53
# 1            2   19   Male        Sweater  Clothing               64
# 2            3   50   Male          Jeans  Clothing               73
# 3            4   21   Male        Sandals  Footwear               90
# 4            5   45   Male         Blouse  Clothing               49
#
#         location size      color  season  review_rating subscription_status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
#    shipping_type discount_applied promo_code_used  previous_purchases  \
# ...

# %%
# partion age into age groups
labels = ['Young Adult', 'Adult', 'Middle -aged', 'Senior']
df['age_group'] = pd.qcut(df['age'],q=4, labels = labels)
df[['age', 'age_group']].head(10)
# Out:
#    age     age_group
# 0   55  Middle -aged
# 1   19   Young Adult
# 2   50  Middle -aged
# 3   21   Young Adult
# 4   45  Middle -aged
# 5   46  Middle -aged
# 6   63        Senior
# 7   27   Young Adult
# 8   26   Young Adult
# 9   57  Middle -aged

# %%
frequency_mapping = {
    'Fortnightly': 14,
    'Weekly': 7,
    'Monthly': 30,
    'Quarterly': 90,
    'Bi-Weekly': 14,
    'Annually': 365,
    'Every 3 Months': 90
}

df['purchase_frequency_days'] = df['frequency_of_purchases'].map(frequency_mapping)

# %%
df['frequency_of_purchases'].unique()
# Out:
# array(['Fortnightly', 'Weekly', 'Annually', 'Quarterly', 'Bi-Weekly',
#        'Monthly', 'Every 3 Months'], dtype=object)

# %%
# df[['discount_applied','promo_code_used']].head(10)
(df['discount_applied'] == df['promo_code_used']).all()
# Out:
# np.True_

# %%
from sqlalchemy import create_engine

# %%
username = "postgres"      # default user
password = "pass123" # the password you set during installation
host = "localhost"         # if running locally
port = "5432"              # default PostgreSQL port
database = "customer_behavior"    # the database you created in pgAdmin

engine = create_engine(f"postgresql+psycopg2://{username}:{password}@{host}:{port}/{database}")

# %%
table_name = "customer"   # choose any table name
df.to_sql(table_name, engine, if_exists="replace", index=False)
# Out:
# 900
